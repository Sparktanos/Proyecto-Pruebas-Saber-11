# %% [markdown]
# # Cifras de Víctimas por Hechos Municipal

# %% [markdown]
# Este Reporte contiene Información del Año en Curso y su actualización se realizar con una periodicidad Mensual. Si usted requiere realizar una consultar de años anteriores por favor diríjase a la página de la Unidad para la Atención y la Reparación Integral a las Víctimas.

# %%
import pyspark.sql.functions as F

# %% [markdown]
# ## Lectura y Descripción del Dataset

# %%
# Cifras de Víctimas por Hechos Municipal https://www.datos.gov.co/Inclusi-n-Social-y-Reconciliaci-n/Cifras-de-V-ctimas-por-Hechos-Municipal/9qih-4vkc/about_data
ds = spark.read \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .option("encoding", "UTF-8") \
    .csv("/Volumes/workspace/pdge(saber-11)/saber11/BRONZE/victimas_municipio.csv")

# %%
ds.printSchema()
